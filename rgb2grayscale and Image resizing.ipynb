# %% [markdown]
# ### Code for RGB To GRAYSCALE

# %%
import cv2
from os import listdir,makedirs
from os.path import isfile,join

path = r'C:\\Users\\admin\\Desktop\\Tabarka Rajab\\tz\\' # Source Folder
dstpath = r'C:\\Users\\admin\\Desktop\\Tabarka Rajab\\tz\\' # Destination Folder

try:
    makedirs(dstpath)
except:
    print ("Directory already exist, images will be written in asme folder")

# Folder won't used
files = [f for f in listdir(path) if isfile(join(path,f))] 

for image in files:
    try:
        img = cv2.imread(os.path.join(path,image))
        gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        dstPath = join(dstpath,image)
        cv2.imwrite(dstPath,gray)
    except:
        print ("{} is not converted".format(image))
# Out:
# Directory already exist, images will be written in asme folder

# %% [markdown]
# ### Code for Image Resizing

# %%
from PIL import Image
import os, sys

path = "C:\\Users\\admin\\Desktop\\Tabarka Rajab\\tz\\"
dirs = os.listdir( path )
print(dirs)

def resize():
    for item in dirs:
        if os.path.isfile(path+item):
            im = Image.open(path+item)
            f, e = os.path.splitext(path+item)
            imResize = im.resize((200,200), Image.ANTIALIAS)
            print(imResize)
            imResize.save(f + '.jpg', 'JPEG', quality=90)

resize()
print(resize())
print(resize(count()))
# Out:
# ['000001_0.jpg', '000001_1.jpg', '000001_2.jpg', '000001_3.jpg', '000001_4.jpg', '000001_5.jpg', '000002_0.jpg', '000002_1.jpg', '000002_2.jpg', '000002_3.jpg', '000002_4.jpg', '000002_5.jpg', '000003_0.jpg', '000003_1.jpg', '000003_2.jpg', '000003_3.jpg', '000003_4.jpg', '000003_5.jpg', '000004_0.jpg', '000004_1.jpg', '000004_2.jpg', '000004_3.jpg', '000004_4.jpg', '000004_5.jpg', '000005_0.jpg', '000005_1.jpg', '000005_2.jpg', '000005_3.jpg', '000005_4.jpg', '000005_5.jpg', '000006_0.jpg', '000006_1.jpg', '000006_2.jpg', '000006_3.jpg', '000006_4.jpg', '000006_5.jpg', '000007_0.jpg', '000007_1.jpg', '000007_2.jpg', '000007_3.jpg', '000007_4.jpg', '000007_5.jpg', '000008_0.jpg', '000008_1.jpg', '000008_2.jpg', '000008_3.jpg', '000008_4.jpg', '000008_5.jpg', '000009_0.jpg', '000009_1.jpg', '000009_2.jpg', '000009_3.jpg', '000009_4.jpg', '000009_5.jpg', '000010_0.jpg', '000010_1.jpg', '000010_2.jpg', '000010_3.jpg', '000010_4.jpg', '000010_5.jpg', '000011_0.jpg', '000011_1.jpg', '000011_2.jpg', '000011_3.jpg', '000011_4.jpg', '000011_5.jpg', '000012_0.jpg', '000012_1.jpg', '000012_2.jpg', '000012_3.jpg', '000012_4.jpg', '000012_5.jpg', '000013_0.jpg', '000013_1.jpg', '000013_2.jpg', '000013_3.jpg', '000013_4.jpg', '000013_5.jpg', '000014_0.jpg', '000014_1.jpg', '000014_2.jpg', '000014_3.jpg', '000014_4.jpg', '000014_5.jpg', '000015_0.jpg', '000015_1.jpg', '000015_2.jpg', '000015_3.jpg', '000015_4.jpg', '000015_5.jpg', '000016_0.jpg', '000016_1.jpg', '000016_2.jpg', '000016_3.jpg', '000016_4.jpg', '000016_5.jpg', '000017_0.jpg', '000017_1.jpg', '000017_2.j

# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# ...
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014588>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014668>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014780>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014128>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B00>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014B38>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921485470>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2791FC626A0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x27921014710>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-0645d865cc97> in <module>
#      15             imResize.save(f + '.jpg', 'JPEG', quality=90)
#      16
# ---> 17 resize()
#      18 print(resize())
#      19 print(resize(count()))
#
# <ipython-input-40-0645d865cc97> in resize()
#      11             im = Image.open(path+item)
#      12             f, e = os.path.splitext(path+item)
# ---> 13             imResize = im.resize((200,200), Image.ANTIALIAS)
#      14             print(imResize)
#      15             imResize.save(f + '.jpg', 'JPEG', quality=90)
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in resize(self, size, resample, box)
#    1802             return im.convert(self.mode)
#    1803
# -> 1804         self.load()
#    1805
#    1806         return self._new(self.im.resize(size, resample, box))
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\ImageFile.py in load(self)
#     239
#     240                             b = b + s
# --> 241                             n, err_code = decoder.decode(b)
#     242                             if n < 0:
#     243                                 break
#
# KeyboardInterrupt:
